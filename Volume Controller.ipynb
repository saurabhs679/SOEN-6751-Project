# %%
import tkinter as tk
import cv2
import mediapipe as mp
from PIL import Image, ImageTk
import subprocess
import time
class CameraApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Hand Detection")
        self.root.geometry("1280x720")  # Set window size

        self.main_frame = tk.Frame(root)
        self.main_frame.pack(expand=True, fill=tk.BOTH)

        self.start_button = tk.Button(self.main_frame, text="Start", command=self.open_camera)
        self.start_button.pack(pady=10)

        self.stop_button = tk.Button(self.main_frame, text="Stop", command=self.stop_camera)
        self.stop_button.pack(pady=10)

        self.cap = None  # Initialize camera capture object
        self.frame_width = None
        self.frame_height = None

        self.hand_detector = mp.solutions.hands.Hands()
        self.drawing_utils = mp.solutions.drawing_utils

        self.status_label = tk.Label(self.main_frame, text="Hand Status: ")
        self.status_label.pack(pady=5)
        self.hand_status = tk.StringVar()
        self.hand_status.set("Unknown")
        self.status_display = tk.Label(self.main_frame, textvariable=self.hand_status)
        self.status_display.pack(pady=5)

        self.camera_label = tk.Label(self.main_frame)
        self.camera_label.pack()
        
        # Initialize debounce variables
        self.last_command_time = 0
        self.debounce_time = 1.0  # Adjust as needed (in seconds)
        
        
    def open_camera(self):
        if self.cap is None or not self.cap.isOpened():
            self.cap = cv2.VideoCapture(0)
            self.show_frame()
        else:
            print("Camera is already open.")

    def show_frame(self):
        ret, frame = self.cap.read()
        if ret:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame = cv2.flip(frame, 1)  # Flip frame horizontally for mirror effect
            frame = cv2.resize(frame, (960, 540))  # Resize frame
            self.frame_height, self.frame_width, _ = frame.shape
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            # Detect hands
            output = self.hand_detector.process(rgb_frame)
            hand_status = self.detect_hand_status(output)
            self.hand_status.set(hand_status)

            if hand_status == "Swiping Left":
                # Check if debounce time has passed since last command execution
                current_time = time.time()
                if current_time - self.last_command_time > self.debounce_time:
                    self.last_command_time = current_time
                    self.play_next()
                    time.sleep(1)  # Add a sleep timer after executing the command
                    #self.increase_volume()
                    
            elif hand_status == "Swiping Right":
                # Check if debounce time has passed since last command execution
                current_time = time.time()
                if current_time - self.last_command_time > self.debounce_time:
                    self.last_command_time = current_time
                    self.play_previous()
                    time.sleep(1)  # Add a sleep timer after executing the command
                    #self.increase_volume()
#             elif hand_status == "Peace":
#                 # Check if debounce time has passed since last command execution
#                 current_time = time.time()
#                 if current_time - self.last_command_time > self.debounce_time:
#                     self.last_command_time = current_time
#                     self.play_pause_spotify()
#                     time.sleep(1)  # Add a sleep timer after executing the command
#                     #self.increase_volume()   
            elif hand_status =="Closed":
                self.increase_volume()
            elif hand_status =="Open":
                self.decrease_volume()
                
            if output.multi_hand_landmarks:
                for hand_landmarks in output.multi_hand_landmarks:
                    self.drawing_utils.draw_landmarks(frame, hand_landmarks, mp.solutions.hands.HAND_CONNECTIONS)

            # Convert the frame to ImageTk format and display it
            img = Image.fromarray(frame)
            img = ImageTk.PhotoImage(img)
            self.camera_label.configure(image=img)
            self.camera_label.image = img

            # Repeat the process
            self.camera_label.after(10, self.show_frame)
        else:
            print("Failed to capture frame.")

#     def detect_hand_status(self, output):
#         if output.multi_hand_landmarks:
#             for hand_landmarks in output.multi_hand_landmarks:
#                 landmarks = hand_landmarks.landmark
#                 thumb_tip = landmarks[4]
#                 index_tip = landmarks[8]
#                 thumb_y = thumb_tip.y * self.frame_height
#                 index_y = index_tip.y * self.frame_height

#                 # Calculate distance between thumb and index finger
#                 distance = abs(thumb_y - index_y)

#                 if distance < 50:
#                     return "Closed"
#                 else:
#                     return "Open"
#         return "Unknown"
#         def detect_hand_status(self, output):
#         if output.multi_hand_landmarks:
#             for hand_landmarks in output.multi_hand_landmarks:
#                 landmarks = hand_landmarks.landmark
#                 thumb_tip = landmarks[4]
#                 index_tip = landmarks[8]
#                 middle_tip = landmarks[12]  # Middle finger tip
#                 thumb_y = thumb_tip.y * self.frame_height
#                 index_y = index_tip.y * self.frame_height
#                 middle_y = middle_tip.y * self.frame_height

#                 # Calculate distance between thumb and index finger
#                 distance = abs(thumb_y - index_y)

#                 # Determine hand status based on thumb and index finger distance
#                 if distance < 50:
#                     return "Closed"
#                 elif middle_y < index_y and middle_y < thumb_y:  # Check if middle finger is above index and thumb
#                     return "Peace"  # Gesture for play/pause
#                 elif thumb_tip.x < index_tip.x:  # Check if thumb is to the left of the index finger
#                     return "Swiping Left"  # Gesture for play previous
#                 elif thumb_tip.x > index_tip.x:  # Check if thumb is to the right of the index finger
#                     return "Swiping Right"  # Gesture for play next

#         return "Unknown"
    
    
    def detect_hand_status(self, output):
        if output.multi_hand_landmarks:
            for hand_landmarks in output.multi_hand_landmarks:
                landmarks = hand_landmarks.landmark
                thumb_tip = landmarks[4]
                index_tip = landmarks[8]
                middle_tip = landmarks[12] 
                thumb_y = thumb_tip.y * self.frame_height
                index_y = index_tip.y * self.frame_height
                middle_y = middle_tip.y * self.frame_height

                # Calculate distance between thumb and index finger
                distance = abs(thumb_y - index_y)

                # Determine hand status based on thumb and index finger distance
                if distance < 50:
                    return "Closed"
                elif middle_y < index_y and middle_y < thumb_y:  # Check if middle finger is above index and thumb
                    return "Peace Sign"
                elif thumb_tip.x < index_tip.x:  # Check if thumb is to the left of the index finger
                    return "Swiping Left"  # Gesture for play previous
                elif thumb_tip.x > index_tip.x:  # Check if thumb is to the right of the index finger
                    return "Swiping Right"  # Gesture for play next
                else:
                    return "Open"  # Gesture for hand open

        return "Unknown"
    
    def increase_volume(self):
        subprocess.run(["osascript", "-e", "set volume output volume (output volume of (get volume settings) + 5)"])
    def decrease_volume(self):
        subprocess.run(["osascript", "-e", "set volume output volume (output volume of (get volume settings) - 5)"])
    # def play_previous():
    #     subprocess.run(["osascript", "-e", "tell application \"System Events\" to key code 97 using {fn down}"])
    def play_next(self):
        subprocess.run(["osascript", "-e", "tell application \"Spotify\" to next track"])

    def play_previous(self):
        subprocess.run(["osascript", "-e", "tell application \"Spotify\" to previous track"])
        
    def play_pause_spotify():
        subprocess.run(["osascript", "-e", "tell application \"Spotify\" to playpause"])

    
    def stop_camera(self):
        if self.cap is not None and self.cap.isOpened():
            self.cap.release()
        else:
            print("Camera is not open.")

root = tk.Tk()
app = CameraApp(root)
root.mainloop()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709935664.999835 7704813 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1 Pro
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Failed to capture frame.

# %%
pip install pynput
# Out:
# Requirement already satisfied: pynput in /opt/anaconda3/lib/python3.11/site-packages (1.7.6)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from pynput) (1.16.0)
# Requirement already satisfied: pyobjc-framework-ApplicationServices>=8.0 in /opt/anaconda3/lib/python3.11/site-packages (from pynput) (10.1)
# Requirement already satisfied: pyobjc-framework-Quartz>=8.0 in /opt/anaconda3/lib/python3.11/site-packages (from pynput) (10.1)
# Requirement already satisfied: pyobjc-core>=10.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyobjc-framework-ApplicationServices>=8.0->pynput) (10.1)
# Requirement already satisfied: pyobjc-framework-Cocoa>=10.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyobjc-framework-ApplicationServices>=8.0->pynput) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreText>=10.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyobjc-framework-ApplicationServices>=8.0->pynput) (10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyobjc
# Out:
# Requirement already satisfied: pyobjc in /Users/bunty/anaconda3/lib/python3.11/site-packages (10.1)
# Requirement already satisfied: pyobjc-core==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Automator==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreData==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Collecting pyobjc-framework-CoreServices==10.1 (from pyobjc)
#   Obtaining dependency information for pyobjc-framework-CoreServices==10.1 from https://files.pythonhosted.org/packages/b9/a2/40e3ea57d2db98dfe7673cf644da5f15d186f1d4d90ffc57ec19c1f71b20/pyobjc_framework_CoreServices-10.1-cp36-abi3-macosx_11_0_universal2.whl.metadata
#   Using cached pyobjc_framework_CoreServices-10.1-cp36-abi3-macosx_11_0_universal2.whl.metadata (2.4 kB)
# Requirement already satisfied: pyobjc-framework-CoreText==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Quartz==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Security==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-WebKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-NetFS==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-libxpc==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Accounts==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-EventKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Social==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-GameKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AVKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-GameController==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MapKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Contacts==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Metal==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Photos==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Intents==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreML==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Vision==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Network==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-OSLog==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PushKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Speech==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AdServices==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CallKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PassKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MailKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PHASE==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Cinematic==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Symbols==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==10.1 in /Users/bunty/anaconda3/lib/python3.11/site-packages (from pyobjc) (10.1)
# Using cached pyobjc_framework_CoreServices-10.1-cp36-abi3-macosx_11_0_universal2.whl (39 kB)
# Installing collected packages: pyobjc-framework-CoreServices
#   Attempting uninstall: pyobjc-framework-CoreServices
#     Found existing installation: pyobjc-framework-CoreServices 9.0
#     Uninstalling pyobjc-framework-CoreServices-9.0:
#       Successfully uninstalled pyobjc-framework-CoreServices-9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.3 requires pyqt5<5.16, which is not installed.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# Successfully installed pyobjc-framework-CoreServices-10.1
# Note: you may need to restart the kernel to use updated packages.
